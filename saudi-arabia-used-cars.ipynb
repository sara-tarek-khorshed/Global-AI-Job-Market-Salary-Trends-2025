# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df =pd.read_csv("/kaggle/input/saudi-arabia-used-cars-dataset/UsedCarsSA_Clean_EN.csv")

# %%
df
# Out:
#            Make          Type  Year       Origin   Color    Options  \
# 0      Chrysler          C300  2018        Saudi   Black       Full
# 1        Nissan        Patrol  2016        Saudi   White       Full
# 2        Nissan         Sunny  2019        Saudi  Silver   Standard
# 3       Hyundai       Elantra  2019        Saudi    Grey   Standard
# 4       Hyundai       Elantra  2019        Saudi  Silver  Semi Full
# ...         ...           ...   ...          ...     ...        ...
# 8030       Audi            A6  2015        Saudi  Silver       Full
# 8031  Chevrolet        Camaro  2010        Saudi  Silver       Full
# 8032     Toyota  Land Cruiser  2013  Gulf Arabic   White       Full
# 8033     Nissan        Altima  2011        Saudi  Silver       Full
# 8034   Cadillac         Other  2013        Saudi   White       Full
#
#       Engine_Size Fuel_Type  Gear_Type  Mileage     Region   Price  Negotiable
# ...

# %%
df.head()
# Out:
#        Make     Type  Year Origin   Color    Options  Engine_Size Fuel_Type  \
# 0  Chrysler     C300  2018  Saudi   Black       Full            6       Gas
# 1    Nissan   Patrol  2016  Saudi   White       Full            5       Gas
# 2    Nissan    Sunny  2019  Saudi  Silver   Standard            2       Gas
# 3   Hyundai  Elantra  2019  Saudi    Grey   Standard            2       Gas
# 4   Hyundai  Elantra  2019  Saudi  Silver  Semi Full            2       Gas
#
#    Gear_Type  Mileage  Region   Price  Negotiable
# 0  Automatic   103000  Riyadh  114000       False
# 1  Automatic     5448  Riyadh       0        True
# 2  Automatic    72418  Riyadh   27500       False
# 3  Automatic   114154  Riyadh   43000       False
# 4  Automatic    41912  Riyadh   59500       False

# %%
df.tail(10)
# Out:
#             Make          Type  Year       Origin   Color    Options  \
# 8025  Mitsubishi        Pajero  2011        Saudi    Navy  Semi Full
# 8026  Mitsubishi        Lancer  2009        Other    Grey   Standard
# 8027        Ford          Edge  2013        Saudi   Black   Standard
# 8028         Kia       Cadenza  2012        Saudi   Black   Standard
# 8029         Kia       Sorento  2006        Saudi    Navy       Full
# 8030        Audi            A6  2015        Saudi  Silver       Full
# 8031   Chevrolet        Camaro  2010        Saudi  Silver       Full
# 8032      Toyota  Land Cruiser  2013  Gulf Arabic   White       Full
# 8033      Nissan        Altima  2011        Saudi  Silver       Full
# 8034    Cadillac         Other  2013        Saudi   White       Full
#
#       Engine_Size Fuel_Type  Gear_Type  Mileage     Region  Price  Negotiable
# 8025            6       Gas  Automatic   140000     Jubail  38000       False
# ...

# %%
df.duplicated().sum ()
# Out:
# 3

# %%
duplicates = df[df.duplicated(keep=False)]
print(duplicates)
# Out:
#         Make    Type  Year Origin  Color    Options  Engine_Size Fuel_Type  \
# 1354    Ford  Taurus  2015  Other    Red       Full            4       Gas
# 1387    Ford  Taurus  2019  Other    Red  Semi Full            4       Gas
# 2027    Ford  Taurus  2015  Other    Red       Full            4       Gas
# 3201    Ford  Taurus  2019  Other    Red  Semi Full            4       Gas
# 4272  Toyota   Camry  2013  Saudi  White       Full            2       Gas
# 5070  Toyota   Camry  2013  Saudi  White       Full            2       Gas
#
#       Gear_Type  Mileage  Region  Price  Negotiable
# 1354  Automatic   122000  Dammam  69000       False
# 1387  Automatic   108000  Dammam  97000       False
# 2027  Automatic   122000  Dammam  69000       False
# 3201  Automatic   108000  Dammam  97000       False
# 4272  Automatic   185000  Riyadh      0        True
# 5070  Automatic   185000  Riyadh      0        True

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (8032, 13)

# %%
df.isnull().sum()
# Out:
# Make           0
# Type           0
# Year           0
# Origin         0
# Color          0
# Options        0
# Engine_Size    0
# Fuel_Type      0
# Gear_Type      0
# Mileage        0
# Region         0
# Price          0
# Negotiable     0
# dtype: int64

# %%
df.describe()
# Out:
#        Year  Engine_Size    Mileage     Price
# count 8,032        8,032      8,032     8,032
# mean  2,014            3    149,153    53,699
# std       6            2    347,512    71,994
# min   1,963            1        100         0
# 25%   2,012            2     37,000         0
# 50%   2,016            3    101,786    37,000
# 75%   2,018            4    195,000    73,625
# max   2,022            9 20,000,000 1,150,000

# %%
df.describe(include="O")
# Out:
#           Make          Type Origin  Color Options Fuel_Type  Gear_Type  \
# count     8032          8032   8032   8032    8032      8032       8032
# unique      59           381      4     15       3         3          2
# top     Toyota  Land Cruiser  Saudi  White    Full       Gas  Automatic
# freq      2037           372   5961   3477    3191      7858       6968
#
#         Region
# count     8032
# unique      27
# top     Riyadh
# freq      3236

# %%
df["Make"].value_counts().nlargest(10).plot(kind="bar" ,color="skyblue")
plt.title("top 10 car brands" , fontsize=26)
plt.xlabel("brand of car")
plt.ylabel("count of car")
# Out:
# Text(0, 0.5, 'count of car')

# %%
df["Fuel_Type"].value_counts().plot.pie(autopct="%1.2f%%",startangle=0 ,explode=[.5,1,0])
# Out:
# <Axes: ylabel='count'>

# %%
sns.histplot(df["Price"] , bins=20 , kde=True , color ="blue")
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# <Axes: xlabel='Price', ylabel='Count'>

# %%
pd.options.display.float_format = '{:,.0f}'.format

# %%
df["Price"].agg(["min", "max", "mean"])
# Out:
# min            0
# max    1,150,000
# mean      53,699
# Name: Price, dtype: float64

# %%
df["Price"].dtype
# Out:
# dtype('int64')

# %%
fig=px.box(df , y="Price")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df["Price"].head(15)
# Out:
# 0     114000
# 1          0
# 2      27500
# 3      43000
# 4      59500
# 5      72000
# 6      92000
# 7          0
# 8      80000
# 9      32000
# 10     50000
# 11    135000
# 12    153000
# 13    235000
# 14    210000
# Name: Price, dtype: int64

# %%
df[df["Price"]== 0].head(20)
# Out:
#           Make             Type  Year       Origin          Color    Options  \
# 1       Nissan           Patrol  2016        Saudi          White       Full
# 7          GMC            Yukon  2009        Saudi         Bronze       Full
# 18         GMC            Yukon  2018        Saudi          White       Full
# 26      Toyota            Camry  2019        Saudi            Red       Full
# 28      Toyota           Avalon  2008        Other            Red       Full
# 59     Hyundai         Senta fe  2021        Saudi           Navy  Semi Full
# 77         Kia           Optima  2018        Saudi          Brown   Standard
# 85       Lexus               LX  2015        Saudi          White       Full
# 86       Lexus               GX  2018  Gulf Arabic          White  Semi Full
# 95   Chevrolet         Suburban  2015        Other          Black       Full
# 108     Toyota               FJ  2017        Saudi          White       Full
# ...

# %%
df[df["Price"]== 0].head(20).value_counts()
# Out:
# Make       Type             Year  Origin       Color          Options    Engine_Size  Fuel_Type  Gear_Type  Mileage  Region  Price  Negotiable
# Chevrolet  Suburban         2015  Other        Black          Full       5            Gas        Automatic  189000   Riyadh  0      True          1
# Ford       Marquis          2010  Saudi        Blue           Standard   5            Gas        Automatic  290      Taef    0      True          1
# Toyota     Land Cruiser 70  1982  Saudi        Another Color  Standard   4            Gas        Manual     200000   Makkah  0      True          1
#            Land Cruiser     2016  Saudi        White          Full       6            Gas        Automatic  64731    Riyadh  0      True          1
#                             2015  Saudi        White          Full       6            Gas        Automatic  242      Hail    0      True          1
# ...

# %%
df[df["Price"] == 0]["Make"].value_counts().sum()
# Out:
# 2526

# %%
zero_price_cars=df[df["Price"]== 0]
zero_price_table = zero_price_cars.groupby(["Make","Type","Year","Origin","Color","Options","Engine_Size" ,"Fuel_Type"]).size().reset_index(name="Count")

# %%
zero_price_table["Count"].sum()
# Out:
# 2526

# %%
df_price_clean =df[df["Price"]>0]

# %%
zero_price_table
# Out:
#             Make     Type  Year       Origin          Color    Options  \
# 0           Audi       A4  2014  Gulf Arabic          White       Full
# 1           Audi       A6  2008        Saudi         Silver  Semi Full
# 2           Audi       A6  2015  Gulf Arabic  Another Color       Full
# 3           Audi       A6  2016        Saudi         Silver       Full
# 4           Audi       A6  2016        Saudi         Silver       Full
# ...          ...      ...   ...          ...            ...        ...
# 2290  Volkswagen   Passat  2012        Other         Silver  Semi Full
# 2291  Volkswagen   Passat  2014        Saudi          Black       Full
# 2292  Volkswagen   Passat  2014        Saudi           Navy  Semi Full
# 2293  Volkswagen  Touareg  2012        Saudi          Brown       Full
# 2294   Zhengzhou  Pick up  2016        Saudi          White   Standard
#
#       Engine_Size Fuel_Type  Count
# 0               2       Gas      1
# 1               2       Gas      1
# ...

# %%
df_price_clean
# Out:
#            Make     Type  Year Origin   Color    Options  Engine_Size  \
# 0      Chrysler     C300  2018  Saudi   Black       Full            6
# 2        Nissan    Sunny  2019  Saudi  Silver   Standard            2
# 3       Hyundai  Elantra  2019  Saudi    Grey   Standard            2
# 4       Hyundai  Elantra  2019  Saudi  Silver  Semi Full            2
# 5         Honda   Accord  2018  Saudi    Navy       Full            2
# ...         ...      ...   ...    ...     ...        ...          ...
# 8029        Kia  Sorento  2006  Saudi    Navy       Full            4
# 8030       Audi       A6  2015  Saudi  Silver       Full            3
# 8031  Chevrolet   Camaro  2010  Saudi  Silver       Full            4
# 8033     Nissan   Altima  2011  Saudi  Silver       Full            2
# 8034   Cadillac    Other  2013  Saudi   White       Full            4
#
#      Fuel_Type  Gear_Type  Mileage     Region   Price  Negotiable
# ...

# %%
zero_price_cars = df[df["Price"] == 0]

zero_price_table = zero_price_cars.groupby(
    ["Make", "Type", "Year", "Origin", "Color", "Options", "Engine_Size", "Fuel_Type"]
).size().reset_index(name="Count")

# %%
fig = px.histogram(zero_price_table, x="Make", nbins=20 , color ="Color")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_price_clean
# Out:
#            Make     Type  Year Origin   Color    Options  Engine_Size  \
# 0      Chrysler     C300  2018  Saudi   Black       Full            6
# 2        Nissan    Sunny  2019  Saudi  Silver   Standard            2
# 3       Hyundai  Elantra  2019  Saudi    Grey   Standard            2
# 4       Hyundai  Elantra  2019  Saudi  Silver  Semi Full            2
# 5         Honda   Accord  2018  Saudi    Navy       Full            2
# ...         ...      ...   ...    ...     ...        ...          ...
# 8029        Kia  Sorento  2006  Saudi    Navy       Full            4
# 8030       Audi       A6  2015  Saudi  Silver       Full            3
# 8031  Chevrolet   Camaro  2010  Saudi  Silver       Full            4
# 8033     Nissan   Altima  2011  Saudi  Silver       Full            2
# 8034   Cadillac    Other  2013  Saudi   White       Full            4
#
#      Fuel_Type  Gear_Type  Mileage     Region   Price  Negotiable
# ...

# %%
fig=px.box(df_price_clean , y="Price" )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.scatter(df_price_clean , x="Make" ,y="Price" ,hover_data =["Color","Year","Type"]   , color="Origin")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(df ,x="Mileage",
             
             title="Price Distribution by Fuel Type")

fig.update_layout(template="plotly_white")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.scatter(df , x="Mileage" ,y="Price" ,hover_data =["Color","Year","Type"]   , color="Gear_Type")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df["Mileage"].sort_values(ascending=False).head(10)
# Out:
# 7391    20000000
# 4475     9999999
# 5068     4900000
# 4675     4691232
# 7525     4500000
# 6616     4430000
# 7270     4358765
# 1564     4090000
# 3404     4010000
# 5539     4000000
# Name: Mileage, dtype: int64

# %%
fig=px.scatter(df , x="Engine_Size" ,y="Price" ,hover_data =["Color","Year","Type"]   , color="Fuel_Type")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(df, x="Fuel_Type", y="Price", color="Fuel_Type",
             title="Price Distribution by Fuel Type")

fig.update_layout(template="plotly_white")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df["Options"].value_counts().plot.pie(autopct="%1.2f%%",startangle=90 ,explode=[0,0,0])
# Out:
# <Axes: ylabel='count'>
